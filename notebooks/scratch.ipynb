# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import pandas as pd
import json
from alpha_vantage.timeseries import TimeSeries

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f"""https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey={os.getenv('stock_api')}"""
r = requests.get(url)
data = r.json()

# %%
ts = TimeSeries(os.getenv('stock_api'), output_format='pandas')
data,meta = ts.get_intraday('IBM', interval='1min', outputsize='full')

# %%
meta
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume',
#  '2. Symbol': 'IBM',
#  '3. Last Refreshed': '2025-02-18 19:59:00',
#  '4. Interval': '1min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
data
# Out:
#                       1. open   2. high    3. low  4. close  5. volume
# date
# 2025-02-18 19:59:00  263.3300  263.3300  263.0800  263.0800       21.0
# 2025-02-18 19:54:00  263.3400  263.3400  263.3400  263.3400        1.0
# 2025-02-18 19:44:00  263.3400  263.3500  263.3400  263.3500       56.0
# 2025-02-18 19:38:00  263.0800  263.0800  263.0800  263.0800        5.0
# 2025-02-18 19:36:00  263.0700  263.0700  263.0700  263.0700        2.0
# ...                       ...       ...       ...       ...        ...
# 2025-01-21 04:04:00  223.4927  223.4927  223.4927  223.4927       12.0
# 2025-01-21 04:03:00  223.3040  223.3040  223.3040  223.3040       54.0
# 2025-01-21 04:02:00  223.4927  223.4927  223.4927  223.4927        6.0
# 2025-01-21 04:01:00  223.4828  223.4927  223.2543  223.4927       12.0
# 2025-01-21 04:00:00  224.1582  224.1582  223.0854  223.2940      305.0
#
# [13679 rows x 5 columns]

# %%
import yfinance as yf

nifty = yf.Ticker("^NSEI")
data = nifty.history(period="1d", interval="1m")

# %%
data
# Out:
#                                    Open          High           Low  \
# Datetime
# 2025-02-19 09:15:00+05:30  22839.400391  22839.400391  22818.900391
# 2025-02-19 09:16:00+05:30  22825.449219  22827.949219  22816.199219
# 2025-02-19 09:17:00+05:30  22825.699219  22852.500000  22824.400391
# 2025-02-19 09:18:00+05:30  22846.199219  22859.250000  22839.400391
# 2025-02-19 09:19:00+05:30  22858.050781  22863.699219  22852.150391
# ...                                 ...           ...           ...
# 2025-02-19 15:25:00+05:30  22926.449219  22927.300781  22922.150391
# 2025-02-19 15:26:00+05:30  22925.650391  22933.250000  22925.099609
# 2025-02-19 15:27:00+05:30  22930.849609  22932.849609  22927.699219
# 2025-02-19 15:28:00+05:30  22931.500000  22932.400391  22921.050781
# 2025-02-19 15:29:00+05:30  22919.949219  22925.349609  22912.349609
#
#                                   Close  Volume  Dividends  Stock Splits
# Datetime
# ...

# %%
nifty_50_symbols = [
    "RELIANCE.NS", "TCS.NS", "HDFCBANK.NS", "INFY.NS", "HINDUNILVR.NS",
    "ICICIBANK.NS", "KOTAKBANK.NS", "SBIN.NS", "BHARTIARTL.NS", "LT.NS",
    "HCLTECH.NS", "AXISBANK.NS", "BAJFINANCE.NS", "ASIANPAINT.NS", "MARUTI.NS",
    "TITAN.NS", "SUNPHARMA.NS", "NTPC.NS", "ONGC.NS", "NESTLEIND.NS",
    "POWERGRID.NS", "ULTRACEMCO.NS", "WIPRO.NS", "COALINDIA.NS", "IOC.NS",
    "SHREECEM.NS", "JSWSTEEL.NS", "TECHM.NS", "ADANIPORTS.NS", "BAJAJ-AUTO.NS",
    "GRASIM.NS", "TATASTEEL.NS", "HDFCLIFE.NS", "DRREDDY.NS", "DIVISLAB.NS",
    "CIPLA.NS", "UPL.NS", "EICHERMOT.NS", "HEROMOTOCO.NS", "BPCL.NS",
    "INDUSINDBK.NS", "SBILIFE.NS", "BAJAJFINSV.NS", "HDFC.NS", "ITC.NS",
    "MM.NS", "TATAMOTORS.NS", "VEDL.NS", "ZEEL.NS", "BRITANNIA.NS"
]

# Fetch real-time data for all Nifty 50 stocks
data2 = yf.download(nifty_50_symbols, period="1d", interval="1m", group_by="ticker")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  50 of 50 completed
#
# 2 Failed downloads:
# ['HDFC.NS', 'MM.NS']: YFPricesMissingError('possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")')

# %%
data2
# Out:
# Ticker                        TITAN.NS                                         \
# Price                             Open         High          Low        Close
# 2025-02-19 03:45:00+00:00  3219.000000  3224.500000  3206.300049  3223.550049
# 2025-02-19 03:46:00+00:00  3222.350098  3222.350098  3215.000000  3215.000000
# 2025-02-19 03:47:00+00:00  3214.050049  3217.000000  3212.399902  3217.000000
# 2025-02-19 03:48:00+00:00  3216.449951  3221.850098  3216.000000  3221.850098
# 2025-02-19 03:49:00+00:00  3220.250000  3220.250000  3214.250000  3216.149902
# ...                                ...          ...          ...          ...
# 2025-02-19 09:55:00+00:00  3210.399902  3212.199951  3209.850098  3210.800049
# 2025-02-19 09:56:00+00:00  3211.000000  3212.000000  3211.000000  3211.850098
# 2025-02-19 09:57:00+00:00  3211.800049  3214.899902  3211.800049  3212.550049
# 2025-02-19 09:58:00+00:00  3212.600098  3212.600098  3211.250000  3211.649902
# ...
